# %%
from IPython.core.display import display, HTML
from keplergl import KeplerGl
map_1 = KeplerGl()
display(map_1,HTML("<style>.container { width:100% height:100% !important; }</style>"))
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl()
# <style>.container { width:100% height:100% !important; }</style>

# %%
import pandas as pd
df = pd.read_csv("C:/Users/HP/Downloads/earthquake_dataset.csv").head(11)
df = df[['time','latitude','longitude','mag','depth']]
map_1.add_data(data=df, name='data_1')

# %%
import pandas as pd
df = pd.read_csv("C:/Users/HP/Downloads/earthquake_dataset.csv")
df
# Out:
#                            time  latitude  longitude   depth  mag magType  \
# 0      2021-09-17T22:22:53.164Z   38.5479    73.4276  112.62  4.1      mb
# 1      2021-09-17T22:06:44.414Z   38.5006    73.4455  113.17  4.9      mb
# 2      2021-09-17T19:12:03.123Z   30.1198    69.3124   31.99  4.7      mb
# 3      2021-09-15T00:41:12.633Z   36.3079    70.6106  118.70  4.3      mb
# 4      2021-09-14T10:40:05.832Z   33.2664    72.2158   10.00  4.7      mb
# ...                         ...       ...        ...     ...  ...     ...
# 13451  1972-01-20T11:36:29.000Z   36.3740    70.8300  211.90  6.2      mw
# 13452  1972-01-12T18:37:23.000Z   37.6360    75.0140   99.20  5.7      mw
# 13453  1971-11-18T07:31:34.000Z   38.4040    66.6390   29.20  5.6      mw
# 13454  1971-08-04T00:24:37.000Z   36.4120    70.8080  201.60  5.9      mw
# 13455  1971-05-09T19:26:34.000Z   35.5120    71.1600   69.10  5.7      mw
#
#        nst    gap   dmin   rms  ...                   updated  \
# ...

# %%
mask = (df['latitude'] >= 24.0) & (df['latitude'] < 28.0) & (df['longitude'] >= 60.0) & (df['longitude'] < 64.0)
mask
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13451    False
# 13452    False
# 13453    False
# 13454    False
# 13455    False
# Length: 13456, dtype: bool

# %%
df[mask]
# Out:
#                            time  latitude  longitude  depth  mag magType  nst  \
# 29     2021-08-26T00:07:48.081Z   25.0595    61.3743   10.0  4.1      mb  NaN
# 121    2021-05-24T21:15:18.761Z   27.4192    62.7334   10.0  4.3      mb  NaN
# 195    2021-02-13T04:34:32.933Z   25.4683    61.8035   10.0  4.3      mb  NaN
# 421    2020-06-17T06:58:17.560Z   25.0244    63.2549   10.0  4.6      mb  NaN
# 449    2020-05-15T12:52:45.818Z   25.9932    62.2797   10.0  4.7      mb  NaN
# ...                         ...       ...        ...    ...  ...     ...  ...
# 13374  1973-06-08T17:56:59.100Z   26.4620    61.1150   33.0  4.6      mb  NaN
# 13387  1973-04-26T14:30:05.400Z   27.0920    60.8370   46.0  5.2      mb  NaN
# 13402  1973-04-02T01:27:09.000Z   27.0910    61.5570   33.0  5.0      mb  NaN
# 13435  1973-01-13T14:14:41.100Z   25.5810    63.8950   50.0  5.0      mb  NaN
# 13448  1972-08-06T01:12:51.000Z   25.0310    61.2780   25.0  5.7      mw  NaN
#
# ...

# %%
df[mask].to_csv('C:/Users/HP/Downloads/1st_part.csv', index=False)

# %%
mask2 = (df['latitude'] >= 28.0) & (df['latitude'] < 32.0) & (df['longitude'] >= 64.0) & (df['longitude'] < 68.0)
mask2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13451    False
# 13452    False
# 13453    False
# 13454    False
# 13455    False
# Length: 13456, dtype: bool

# %%
df[mask2].to_csv('C:/Users/HP/Downloads/2nd_part.csv', index=False)

# %%
df[mask2]
# Out:
#                            time  latitude  longitude  depth  mag magType  nst  \
# 118    2021-05-27T08:54:33.708Z   30.0738    66.2502  10.00  4.7      mb  NaN
# 119    2021-05-27T00:38:27.680Z   30.0988    66.2734  10.00  4.2      mb  NaN
# 120    2021-05-25T22:12:19.297Z   30.2556    66.4514  10.00  4.2      mb  NaN
# 153    2021-04-10T21:49:38.394Z   28.3413    67.2682  10.00  4.3      mb  NaN
# 154    2021-04-10T15:18:24.540Z   28.0620    66.6139  34.15  4.1      mb  NaN
# ...                         ...       ...        ...    ...  ...     ...  ...
# 13065  1975-09-28T10:19:40.300Z   30.2600    66.2890   8.00  4.2      mb  NaN
# 13099  1975-07-18T09:30:12.200Z   30.9740    66.6990  35.00  4.9      mb  NaN
# 13309  1974-02-22T07:06:32.600Z   29.6870    67.6000  33.00  5.0      mb  NaN
# 13369  1973-06-25T20:22:26.500Z   28.3220    66.9210  72.00  4.3      mb  NaN
# 13420  1973-02-04T19:25:48.300Z   31.6720    67.2640  40.00  3.9      mb  NaN
#
# ...

# %%
mask3 = (df['latitude'] >= 32.0) & (df['latitude'] < 36.0) & (df['longitude'] >= 68.0) & (df['longitude'] < 72.0)
df[mask3].to_csv('C:/Users/HP/Downloads/3rd_part.csv', index=False)

# %%
df[mask3]
# Out:
#                            time  latitude  longitude   depth  mag magType  \
# 39     2021-08-16T07:31:10.679Z   35.7887    68.5348   33.68  4.4      mb
# 92     2021-06-24T23:04:44.289Z   34.9509    69.0848   16.20  5.1     mww
# 93     2021-06-24T04:58:58.588Z   35.9300    70.9630   91.24  4.4      mb
# 94     2021-06-23T01:09:13.906Z   33.5317    71.5687   33.21  4.7      mb
# 96     2021-06-19T13:59:17.264Z   32.1089    69.8552   51.42  4.5      mb
# ...                         ...       ...        ...     ...  ...     ...
# 13436  1973-01-12T23:39:25.900Z   35.9920    70.5810  126.00  5.2      mb
# 13438  1973-01-10T03:02:32.100Z   32.6410    68.3320   18.00  4.8      mb
# 13440  1972-12-28T16:57:47.000Z   34.7320    70.3960   64.10  5.6      mw
# 13441  1972-11-16T12:43:06.000Z   35.6480    69.8530  116.00  5.9      mw
# 13455  1971-05-09T19:26:34.000Z   35.5120    71.1600   69.10  5.7      mw
#
#        nst   gap   dmin   rms  ...                   updated  \
# ...

# %%
mask4 = (df['latitude'] >= 36.0) & (df['latitude'] < 40.0) & (df['longitude'] >= 72.0) & (df['longitude'] < 76.0)
df[mask4].to_csv('C:/Users/HP/Downloads/4th_part.csv', index=False)
df[mask4]
# Out:
#                            time  latitude  longitude   depth  mag magType  \
# 0      2021-09-17T22:22:53.164Z   38.5479    73.4276  112.62  4.1      mb
# 1      2021-09-17T22:06:44.414Z   38.5006    73.4455  113.17  4.9      mb
# 8      2021-09-11T01:34:05.876Z   37.5399    72.2862  190.07  4.0      mb
# 13     2021-09-08T05:20:06.964Z   38.1508    73.2564   62.21  5.3      mb
# 14     2021-09-07T13:34:12.648Z   38.1266    73.1869   38.59  4.7      mb
# ...                         ...       ...        ...     ...  ...     ...
# 13404  1973-03-26T07:58:42.700Z   38.3330    73.9340  123.00  5.3      mb
# 13412  1973-02-24T09:16:31.300Z   37.7890    73.0740  228.00  3.7      mb
# 13433  1973-01-15T18:48:43.600Z   36.0640    73.3650   33.00  3.8      mb
# 13442  1972-11-12T17:56:54.000Z   38.3580    73.1760  114.70  6.2      mw
# 13452  1972-01-12T18:37:23.000Z   37.6360    75.0140   99.20  5.7      mw
#
#        nst    gap   dmin   rms  ...                   updated  \
# ...
